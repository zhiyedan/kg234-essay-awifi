# %%
# 该模块用来画图
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

import pandas as pd
from bokeh.charts import TimeSeries
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="259a235d-ee97-4959-8232-82ffca702e9e">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('../data/all_split_ts_1hour.csv')
df['time'] = pd.to_datetime(df.time,unit='s')
df = df.set_index('time')
df.head(1)
# Out:
#                      10-77-B0-B9-92-5F  10-77-B0-B9-93-37  10-77-B0-B9-96-8F  \
# time
# 2018-03-09 16:00:00                0.0                0.0                0.0
#
#                      10-77-B0-B9-97-8F  10-77-B0-B9-98-2F  10-77-B0-B9-99-C7  \
# time
# 2018-03-09 16:00:00                0.0                0.0                0.0
#
#                      10-77-B0-B9-9B-47  10-77-B0-B9-9C-D7  10-77-B0-B9-A1-17  \
# time
# 2018-03-09 16:00:00                0.0               53.0                0.0
#
#                      10-77-B0-B9-AA-67           ...            \
# time                                             ...
# 2018-03-09 16:00:00                0.0           ...
#
#                      74-C9-A3-52-CD-F7  74-C9-A3-52-CE-B7  74-C9-A3-52-CF-27  \
# time
# 2018-03-09 16:00:00                0.0                0.0              322.0
#
#                      74-C9-A3-52-CF-67  74-C9-A3-52-CF-BF  74-C9-A3-52-D0-17  \
# time
# ...

# %%
ts = df.T.values
ts1 = pd.Series(ts[0],df.index)
ts2 = pd.Series(ts[3],df.index)
ts1.plot()
ts2.plot()
plt.show()

# %%
rand_col = random.sample(df.columns.values.tolist(),5)
noise_col = [13, 20, 31, 49, 87, 88, 110, 114, 120, 124, 127, 239, 243, 244, 256, 267, 274, 279, 284, 288, 296, 298, 311, 340, 346, 362, 392, 416, 441, 442, 445, 446, 448, 450, 462, 519, 540, 542, 543, 546, 577, 592, 598, 605, 618, 626, 632, 641, 697, 703, 732, 749, 771, 779, 788, 823, 828, 829, 838, 839]
noise_data = random.sample(df.columns[noise_col].values.tolist(),3)
dff = df[noise_data]
dff.plot()
plt.show()
